# %% [markdown]
# ### IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMPORT SINUSOID SOUND CAPTURED BY ESP32

# %%
data = pd.read_csv("sound_sinusoid_captured.csv")
data
# Out:
#        Sample
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 96571      42
# 96572      50
# 96573      54
# 96574      42
# 96575      42
#
# [96576 rows x 1 columns]

# %% [markdown]
# ### GENERATE TIME

# %%
samplingFreq = 10000 # Disampling pada frekuensi 10 kHz = 10000 sampel/s
tlims = [0,3]       # batas waktu dalam detik (s)
time = np.linspace(tlims[0],tlims[1],(tlims[1]-tlims[0])*samplingFreq)

# %% [markdown]
# ### PLOT CAPTURED SOUND

# %%
plt.plot(time[2000:3000], data[2000:3000])
# plt.plot(time, data)
plt.title("sound sample")
plt.xlabel("time")
plt.ylabel("magnitude")
# Out:
# Text(0, 0.5, 'magnitude')
