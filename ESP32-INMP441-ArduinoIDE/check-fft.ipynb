# %% [markdown]
# ### IMPORT LIBRARY

# %%
import numpy as np
from numpy import sin, cos, pi
from scipy.fftpack import fft, fftfreq, ifft
import matplotlib.pyplot as plt
import librosa
import IPython.display as ipd
import soundfile as sf
import pandas as pd

# %% [markdown]
# ### IMPORT SOUND

# %%
x = pd.read_csv("Proof ESP32 Sucks for Sound\sound_sinusoid_captured.csv")
x = x.values.flatten()
x
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23888\790983684.py:1: SyntaxWarning: invalid escape sequence '\s'
#   x = pd.read_csv("Proof ESP32 Sucks for Sound\sound_sinusoid_captured.csv")
# array([ 0,  0,  0, ..., 54, 42, 42])

# %% [markdown]
# ### COMPUTE FAST FOURIER TRANSFORM

# %%
#compute spectrum
sampling_rate = 10000
spectrum=fft(x)
N = len(x)
F=fftfreq(N,1/sampling_rate)
Fpositive=np.where(F>=0)

# %% [markdown]
# ### PLOT DATA IN FREQUENCY DOMAIN

# %%
t = np.array(range(0, len(x))) / sampling_rate

plt.plot(F[Fpositive],np.absolute(spectrum[Fpositive])/N)
# plt.plot(F,np.absolute(spectrum)/N)
plt.xlabel('Frequency(Hz)',fontsize=14)
plt.ylabel('Amplitude Spectrum',fontsize=14)
plt.grid()
