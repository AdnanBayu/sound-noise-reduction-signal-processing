# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sound_samples2.csv")
data
# Out:
#        Sample
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 98015      -4
# 98016       4
# 98017      62
# 98018      -4
# 98019      30
#
# [98020 rows x 1 columns]

# %%
time = np.arange(0, len(data))
time
# Out:
# array([    0,     1,     2, ..., 98017, 98018, 98019])

# %%
plt.plot(time, data)
plt.title("sound sample")
plt.xlabel("time")
plt.ylabel("magnitude")
# Out:
# Text(0, 0.5, 'magnitude')
